# %% [markdown]
# <a href="https://colab.research.google.com/github/krkhalil/Python-Project-DataScience/blob/main/python_project_datascience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **MS Data Science Batch2020**
# **Real State data Expolatory Analysisi**
#
#
# **Submit By**
# ```
# khalil ul Rehman
# F2020313010
# Farhan Ahmad
# F2020313023
# Shahzada Farhan MEhmood
# F2020313004
# ```
# **Submit to**
# ```
# Muhammad Shaheryar
# ```

# %% [markdown]
# **Here is importing the necessary Liberuries**
# ```
# pandas
# matplotlib
# numpy
# sklearn
# ```

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np 
from sklearn import linear_model
lm = linear_model.LinearRegression()

# %% [markdown]
# **Access the data use of Drop and Describe**
# ```
# 1. Getting the live data from the github repo set by my own due to colab reload and truncate the file condition
# 2. using the drop function to drop the column id on axis=1 and set the remeninf into new data frame
# 3. Third one describe is used to get some standard information from the data set
# ```

# %%
df = pd.read_csv('https://raw.githubusercontent.com/krkhalil/Real-Estate-Investment-Trust/master/realestate_data.csv')

df_new = df.drop(['id','zipcode','lat','long'], axis=1)
df_new.describe()
# Out:
#               price      bedrooms  ...  sqft_living15     sqft_lot15
# count  2.161300e+04  21613.000000  ...   21613.000000   21613.000000
# mean   5.400881e+05      3.370842  ...    1986.552492   12768.455652
# std    3.671272e+05      0.930062  ...     685.391304   27304.179631
# min    7.500000e+04      0.000000  ...     399.000000     651.000000
# 25%    3.219500e+05      3.000000  ...    1490.000000    5100.000000
# 50%    4.500000e+05      3.000000  ...    1840.000000    7620.000000
# 75%    6.450000e+05      4.000000  ...    2360.000000   10083.000000
# max    7.700000e+06     33.000000  ...    6210.000000  871200.000000
#
# [8 rows x 16 columns]

# %% [markdown]
# **Value Count and to frame functions**
# ```
# *   Here is two importatn function to count the unique values of the column without finding the unique values
# *   second one to_frame() is used to set the result into a data frame like shape
# ```

# %%
df_new['floors'].value_counts().to_frame()
# Out:
#      floors
# 1.0   10680
# 2.0    8241
# 1.5    1910
# 3.0     613
# 2.5     161
# 3.5       8

# %% [markdown]
# **Box Plot**
# ```
# A box and whisker plot is a way of summarizing a set of data measured on an interval scale. It is often used in explanatory data analysis.
# This type of graph is used to show the shape of the distribution, its central value, and its variability
# here is two column 'price' and the other is 'waterfront' here we can see the
# upperwhisker and the lowerwhisker and the quartile between the price and
# the waterfront
# ```

# %%
sns.boxplot(y=df_new["price"],x=df_new['waterfront']);
plt.show()

# %% [markdown]
# **Seaborn Rgression Plot**
# ```
# In the spirit of Tukey, the regression plots in seaborn are primarily
# intended to add a visual guide that helps to emphasize patterns in a dataset
# during exploratory data analyses. That is to say that seaborn is not itself a
# package for statistical analysis.
# here i am getting it to between 'price' and 'sqft_above' on y-axis here is price and on x-axis is square feet above portion
# ```

# %%
ax = sns.regplot(x="sqft_above", y="price", data=df_new)

# %% [markdown]
# **Duplicated and isna function**
#
#
# ```
# Here i am trying to idetify the sum of duplicated vale which is 7 and
# there is no null value in the data set
# ```

# %%
dp=df.duplicated().sum()
dp
df.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# **Heatmap**
# ```
# A heatmap is a two-dimensional graphical representation of data where the
# individual values that are contained in a matrix are represented as colors.
# The seaborn python package allows the creation of annotated heatmaps which
# can be tweaked using Matplotlib tools as per the creator's requirement.
# here i am setting the data frame and called the corellation function to show
# the relevent columns corellation and the annotion of the columns
# here value 1 represent the direct relation with itself and the red one is the
# weakest relation and the yellowish shade show the maximum relation which is
# 88 percent relation
# ```

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df_new.corr(), annot=True)

# %% [markdown]
# **Linear Regression Model training and prediction**
#
#
# *   Getting and setting two columns x and y here x is predicted and y is targeted column
# *   here is object of linearregression model lm from sklearn lm here help to fit the column on model traing
# *   and then lm goes to predict the x values and set it into yhat basically
# yhat is from the formulation which is yhat=bo-b1x
# * The value of 𝑏₀, also called the intercept, shows the point where the
# estimated regression line crosses the 𝑦 axis. It is the value of the
# estimated response 𝑓(𝑥) for 𝑥 = 0. The value of 𝑏₁ determines the slope
# of the estimated regression line.
# * Score is to predict the accurecy of the model here is 49 percent of the model accurecy

# %%
x=df_new[['sqft_living15']]
y=df_new['price']
lm.fit(x,y)
yhat=lm.predict(x)

print('here is the intercept:',lm.intercept_, 'here is coefcient',lm.coef_)
lm.score(x,y)
# Out:
# here is the intercept: -82807.19520853949 here is coefcient [313.55594157]
# 0.3426684607560172

# %% [markdown]
# <h3>Residual Plot</h3>
# <a id='https://colab.research.google.com/drive/1kZyoqKmHUqzJ3uSra0RUM3JlYv8nbmSQ?authuser=1#scrollTo=yI9NYJdiXcon&line=2&uniqifier=1'></a>
#
# <p>A good way to visualize the variance of the data is to use a residual plot.</p>
#
# <p>What is a <b>residual</b>?</p>
#
# <p>The difference between the observed value (y) and the predicted value (Yhat) is called the residual (e). When we look at a regression plot, the residual is the distance from the data point to the fitted regression line.</p>
#
# <p>So what is a <b>residual plot</b>?</p>
#
# <p>A residual plot is a graph that shows the residuals on the vertical y-axis and the independent variable on the horizontal x-axis.</p>
#
# <p>What do we pay attention to when looking at a residual plot?</p>
#
# <p>We look at the spread of the residuals:</p>
#
# <p>- If the points in a residual plot are <b>randomly spread out around the x-axis</b>, then a <b>linear model is appropriate</b> for the data. Why is that? Randomly spread out residuals means that the variance is constant, and thus the linear model is a good fit for this data.</p>

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(df_new['sqft_living15'], df_new['price'])
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Pipeline**
# <p>Data Pipelines simplify the steps of processing the data. We use the module <b>Pipeline</b> to create a pipeline. We also use <b>StandardScaler</b> as a step in our pipeline.</p>
# We create the pipeline, by creating a list of tuples including the name of the model or estimator and its corresponding constructor.
# we input the list as an argument to the pipeline constructor
# We can normalize the data,  perform a transform and fit the model simultaneously.

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

Input=[('scale',StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False)), ('model',LinearRegression())]
pipe=Pipeline(Input)
pipe
# Out:
# Pipeline(memory=None,
#          steps=[('scale',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('polynomial',
#                  PolynomialFeatures(degree=2, include_bias=False,
#                                     interaction_only=False, order='C')),
#                 ('model',
#                  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                   normalize=False))],
#          verbose=False)

# %%
pipe.fit(x,y)
ypipe=pipe.predict(x)
ypipe
pipe.score(x,y)
# Out:
# 0.36050515145735584

# %% [markdown]
# **Describe**

# %%
df_new.describe()
# Out:
#               price      bedrooms  ...  sqft_living15     sqft_lot15
# count  2.161300e+04  21613.000000  ...   21613.000000   21613.000000
# mean   5.400881e+05      3.370842  ...    1986.552492   12768.455652
# std    3.671272e+05      0.930062  ...     685.391304   27304.179631
# min    7.500000e+04      0.000000  ...     399.000000     651.000000
# 25%    3.219500e+05      3.000000  ...    1490.000000    5100.000000
# 50%    4.500000e+05      3.000000  ...    1840.000000    7620.000000
# 75%    6.450000e+05      4.000000  ...    2360.000000   10083.000000
# max    7.700000e+06     33.000000  ...    6210.000000  871200.000000
#
# [8 rows x 16 columns]

# %% [markdown]
# **Difference and the info function**

# %%
df = df[df.columns.difference(['date','id','zipcode','yr_renovated','yr_built','lat','long'])]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bathrooms      21613 non-null  float64
#  1   bedrooms       21613 non-null  int64
#  2   condition      21613 non-null  int64
#  3   floors         21613 non-null  float64
#  4   grade          21613 non-null  int64
#  5   price          21613 non-null  float64
#  6   sqft_above     21613 non-null  int64
#  7   sqft_basement  21613 non-null  int64
#  8   sqft_living    21613 non-null  int64
#  9   sqft_living15  21613 non-null  int64
#  10  sqft_lot       21613 non-null  int64
#  11  sqft_lot15     21613 non-null  int64
#  12  view           21613 non-null  int64
#  13  waterfront     21613 non-null  int64
# dtypes: float64(3), int64(11)
# memory usage: 2.3 MB

# %%
# get columns to plot
columns = df.columns
# create x data
x_data = range(0, df.shape[0])
# create figure and axis
fig, ax = plt.subplots()
# plot each column
for column in columns:
    ax.plot(x_data, df[column], label=column)
# set title and legend
ax.set_title('Iris Dataset')
ax.legend()

# %%
y=df["bedrooms"]
x=df["price"]
plt.scatter(x,y)
plt.title("Price and BedRooms Scatter plot")
plt.xlabel("price")
plt.ylabel("bedrooms")
# Out:
# Text(0, 0.5, 'bedrooms')

# %% [markdown]
# **Corellations between bedrooms and the price**

# %%
sns.regplot(x='bedrooms', y='bathrooms', data=df)
plt.ylim(0,)
# Out:
# (0.0, 16.465173413240574)

# %%
df.describe()
# Out:
#           bathrooms      bedrooms  ...          view    waterfront
# count  21613.000000  21613.000000  ...  21613.000000  21613.000000
# mean       2.114757      3.370842  ...      0.234303      0.007542
# std        0.770163      0.930062  ...      0.766318      0.086517
# min        0.000000      0.000000  ...      0.000000      0.000000
# 25%        1.750000      3.000000  ...      0.000000      0.000000
# 50%        2.250000      3.000000  ...      0.000000      0.000000
# 75%        2.500000      4.000000  ...      0.000000      0.000000
# max        8.000000     33.000000  ...      4.000000      1.000000
#
# [8 rows x 14 columns]

# %% [markdown]
# **Going to apply linear regression Model using single variable**

# %%
reg_df = df
reg_df.head()
# Out:
#    bathrooms  bedrooms  condition  ...  sqft_lot15  view  waterfront
# 0       1.00         3          3  ...        5650     0           0
# 1       2.25         3          3  ...        7639     0           0
# 2       1.00         2          3  ...        8062     0           0
# 3       3.00         4          5  ...        5000     0           0
# 4       2.00         3          3  ...        7503     0           0
#
# [5 rows x 14 columns]

# %%
plt.scatter(reg_df.price,reg_df.bathrooms,reg_df.bedrooms, color='red')
plt.ylabel('price')
plt.xlabel('bedrooms and bathrooms')
plt.show()

# %%
indx = np.random.rand(len(reg_df))<0.8
indx
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
train = reg_df[indx]
test = reg_df[~indx]

# %%
train.shape
# Out:
# (17260, 14)

# %%
#Convert your data independent variable and dependaent variable
train_x = np.asanyarray(train['price'])
train_y = np.asanyarray(train[['bedrooms','bathrooms']])
lm.fit(train_x.reshape(-1,1),train_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('Theta-0: ', lm.coef_)
print('Intercept:' , lm.intercept_)
# Out:
# Theta-0:  [[7.84618524e-07]
#  [1.09681059e-06]]
# Intercept: [2.95038008 1.52255466]

# %%
y_hat = lm.predict([[221900]])
y_hat
# Out:
# array([[3.12448693, 1.76593693]])

# %%
test_x = np.asanyarray(test['price'])
test_y = np.asanyarray(test[['bedrooms','bathrooms']])
test_y_hat = lm.predict(test_x.reshape(-1,1))

# %%
test_x
test_y_hat
# Out:
# array([[3.91153778, 2.86614763],
#        [3.3662279 , 2.10386427],
#        [3.46038212, 2.23548154],
#        ...,
#        [3.31679694, 2.0347652 ],
#        [3.42953485, 2.19236043],
#        [3.74088325, 2.62759133]])

# %%
plt.scatter(train.price,train.bedrooms,train.bathrooms,color='blue')
plt.plot(test_x,test_y_hat,'r-')
plt.show()

# %%
print('Residual Error (MSE): %2f' %np.mean(test_y - test_y_hat) **2)
# Out:
# Residual Error (MSE): 0.000074

# %%
from sklearn.metrics import r2_score
print('R2 Score: %2f'%r2_score(test_y,test_y_hat))
# Out:
# R2 Score: 0.185559

# %% [markdown]
# **Regression using single varable**

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

# %%
x=df[['bedrooms']]
y=df['price']
y
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
lm.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
YHat=lm.predict(x)
YHat
# Out:
# array([494950.73585377, 494950.73585377, 373234.60934194, ...,
#        373234.60934194, 494950.73585377, 373234.60934194])

# %%
print('here is intercept value:',lm.intercept_,'here is Coefficient value:',lm.coef_)
# Out:
# here is intercept value: 129802.35631825868 here is Coefficient value: [121716.12651184]

# %% [markdown]
# **using multiple independent variable and setting into one data frame**

# %%
z = df[['bathrooms','bedrooms','condition','floors','grade','sqft_above','sqft_basement','sqft_living','sqft_living15','sqft_lot','sqft_lot15','view','waterfront']]
z
# Out:
#        bathrooms  bedrooms  condition  ...  sqft_lot15  view  waterfront
# 0           1.00         3          3  ...        5650     0           0
# 1           2.25         3          3  ...        7639     0           0
# 2           1.00         2          3  ...        8062     0           0
# 3           3.00         4          5  ...        5000     0           0
# 4           2.00         3          3  ...        7503     0           0
# ...          ...       ...        ...  ...         ...   ...         ...
# 21608       2.50         3          3  ...        1509     0           0
# 21609       2.50         4          3  ...        7200     0           0
# 21610       0.75         2          3  ...        2007     0           0
# 21611       2.50         3          3  ...        1287     0           0
# 21612       0.75         2          3  ...        1357     0           0
#
# [21613 rows x 13 columns]

# %% [markdown]
# fit the independent and the dependent variable into the model or predicted and targeted value to the model

# %%
lm.fit(z,df['price'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# predicting the Y hat

# %%
yhat=lm.predict(z)
yhat
# Out:
# array([286026.1232662 , 537544.65004293, 157115.39478176, ...,
#        290653.32267675, 443721.22246589, 291133.22925774])

# %% [markdown]
# calculation the R2

# %%
lm.score(z,df['price'])
# Out:
# 0.6070546239949496

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(df['price'],yhat)
# Out:
# 52959661883.33776

# %%
predicted_price = lm.predict(z)
predicted_price
# Out:
# array([286026.1232662 , 537544.65004293, 157115.39478176, ...,
#        290653.32267675, 443721.22246589, 291133.22925774])

# %%
plt.scatter(df['price'],predicted_price,color='blue')
plt.plot(predicted_price,yhat,'r-')
plt.show()

# %% [markdown]
# **Pipe line using Multi variable**

# %%
pipe.fit(z,df_new['price'])
ypipe=pipe.predict(z)
ypipe
pipe.score(z,df_new['price'])
# Out:
# 0.7092096102379186

# %%
sns.regplot(x=ypipe, y='price', data=df_new)
plt.ylim(0,)
# Out:
# (0.0, 8090843.320796864)
